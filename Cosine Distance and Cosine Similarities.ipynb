# %% [markdown]
# ### Eucleadian Distance Formulae

# %%
from IPython.display import Image
Image('C:/Users/Microsoft/Downloads/eclu.jpeg')

# %% [markdown]
# ## Manhatan Distance

# %%
from IPython.display import Image
Image('C:/Users/Microsoft/Downloads/download.png')

# %% [markdown]
# - **Manhattan distance.**
# - **Definition:**
# - The distance between two points measured along axes at right angles.
# - In a plane with `p1` at `(x1, y1)` and `p2` at `(x2, y2).`
# - It is `|x1 - x2|` `+` `|y1 - y2|`. `Lm` distance.

# %% [markdown]
# - In order to measure the similarities we use the distance metrics that are the Mahnatan distance and Euclidean distance matrics.
# - Eucledean distance is measure on the basis of Pythogorous theorem.
# - In the Manhatann distance we do not calculate the hypotenious likewise in ecludean distance.
# - In order to get the manhatan distance we calculate the only oposite and adustance.

# %% [markdown]
# **APPlications of The Eucleandean and Manhatan Distance.**

# %% [markdown]
# - Manhatan distance is use only if we are following the particular pattern in oder to get the measure the distance.e.g.Google map distance assistment in the developed city in U.K.
# - Eucledean distance is use only we have use final and intial point are important than the other things which are in surrounding so we will get the straight foreward distance.

# %% [markdown]
# #### Lets go with Cosine terminology:-

# %% [markdown]
# - 1.Eucleadian distance is also called as `L2` norms.
# - 2.Manhatan distance is also callled as `L1` norms.

# %% [markdown]
# - We have given them nomenclature because we have terminology that `minkowski` it is represented by `αp`.
# - Whenver we have the `p = 1` then It is the `Manhatan distnace` similary If the `p = 0` then that time it represent the `Eucludean Distance.`

# %% [markdown]
# # Cosine Similarities

# %% [markdown]
# - Basically the similarities of the any feature or data it is totally depends how much closly having the distance inbetween them.
# - distance is inversly proportional to similarity of the data.That's means the close the distance close the similarities otherwise vice versa.

# %% [markdown]
# **Formulae:-**
# **`1 - Cosine_similarity = Cosine_Distance`**

# %% [markdown]
# - In order to calculate the cosine similarity we need to find angle between the two axis.

# %%
from IPython.display import Image
Image('C:/Users/Microsoft/Downloads/cosine.png')

# %% [markdown]
# - Here,we can see the two axis of that two points are join to each other at the particular angle.
# - If see take the cosine angle of that `θ`.We will get the Cosine Similarities.
# - `Cosine  Similarities = Cos(θ)`
# - **This consine similarities lies inbeween the -1 and 1 range.**
# - If we calculate the distances from the `cos(90)` then it will be `0`.
# - similary for the `zero degree` it will `1`.
# - Whenever the angel beween the two points `180` then It will gives the `-1` value and at the `270 angle` the value of the cosine similarities will be the `0.`
# - So,basically we are getting the information that cosine will not stay go as the degree of angle increase away from the reference point.
# - **Here the 1 represnet vary closed or almost similar and 0 represent the little close and -1 represent so far.**

# %%
from IPython.display import Image
Image('C:/Users/Microsoft/Downloads/cosine_sim.png')

# %% [markdown]
# ### Cosine Distance.

# %% [markdown]
# - **Cosine Distance = 1 - Cosine Similarity**

# %% [markdown]
# `Cos(θ) = cos(45)= 0.5253`

# %%
cosine_distance = 1- 0.5253
cosine_distance
# Out:
# 0.4747

# %% [markdown]
# `From the above we can see the both the feature we had created the 45 degree of angle those having similarities 0.52 and cosine distance is 0.47 .That indicates the two features are pretty much but not so much similar to each other.`

# %% [markdown]
# ## Thank You !!!
